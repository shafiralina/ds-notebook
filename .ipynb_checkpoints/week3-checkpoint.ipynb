# %%
import requests
from bs4 import BeautifulSoup

# %%
link='https://www.olx.co.id/all-results/q-mobil/?page={}'

# %%
req = requests.get(link.format(1))
soup = BeautifulSoup(req.text, 'lxml')
kumpulan_page = soup.find_all('span',class_='item inline-block')
page_terakhir = kumpulan_page[-1].a['href'].split('=')
page_terakhir = page_terakhir[-1]

# %%
kumpulan_link=[]
hasil=[]
for i in range(1, int(page_terakhir)+1):
    kumpulan_link.append(link.format(i))
    
for link in kumpulan_link[:2]:
    req_mobil = requests.get(link)
    soup_mobil = BeautifulSoup(req_mobil.text, 'lxml')
    seluruh_judul_page = soup_mobil.find_all('a', {'class':'marginright5 link linkWithHash detailsLink'})
    seluruh_harga_page = soup_mobil.find_all('p', {'class':'price large margintop10'})
    seluruh_kota_page = soup_mobil.find_all('p', {'class':'color-9 lheight14 margintop3'})
    seluruh_tanggal_page = soup_mobil.find_all('td', {'class':'rel tcenter'})
    
    
    for judul, harga, kota, tanggal in zip(seluruh_judul_page, seluruh_harga_page, seluruh_kota_page, seluruh_tanggal_page):
        item = {}
        item['judul'] = judul.text.strip()
        item['harga'] = harga.text.strip()
        item['tanggal'] = tanggal.text.strip()
        item['kota'] = kota.find('span').text.strip()
        hasil.append(item)
    
    
from pprint import pprint
pprint(hasil)
df = pd.DataFrame(hasil)
df.to_csv('olx-hal12.csv')
# Out:
# [{'harga': 'Rp 500.000',
#   'judul': 'rental mobil untuk lebaran unit banyak syarat mudah harga murah',
#   'kota': 'Bandung Kota',
#   'tanggal': '6  Mei'},
#  {'harga': 'Rp 569.300.000',
#   'judul': '[Mobil Baru] Mazda CX 5 Promo Lebaran & Bonusnya berlimpah',
#   'kota': 'Jakarta Selatan',
#   'tanggal': '2  Mei'},
#  {'harga': 'Rp 600.000',
#   'judul': 'Sarung jok mobil original',
#   'kota': 'Depok Kota',
#   'tanggal': '22  Apr'},
#  {'harga': 'Rp 4.000.000',
#   'judul': 'velg mobil Suzuki tipe TOKYO L351 HSR R15X7 H8X100-114,3 ET35 SMG',
#   'kota': 'Tangerang Selatan Kota',
#   'tanggal': '11:20'},
#  {'harga': 'Rp 575.000',
#   'judul': 'CARA mengatasi limbung pd mobil?Gampang lngsng psang Damper '
#            'BALANCE aj',
#   'kota': 'Kotawaringin Barat Kab.',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 4.200.000',
#   'judul': 'velg mobil directional hsr ring 15 hole 5x139,7 cocok feroza taft',
#   'kota': 'Gunung Sitoli Kota',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 300.000',
#   'judul': 'kikim vrsi jawon | Garnish Lampu Depan Mobil : GRAND ALL NEW CR-V',
#   'kota': 'Yogyakarta Kota',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 280.000',
#   'judul': 'Selimut mobil h2r bandung bahan kualitas halus46',
#   'kota': 'Serang Kab.',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 175.000',
#   'judul': 'Coper body selimut mobil door mirror m1 suzuki karimun estilo',
#   'kota': 'Gresik Kab.',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 4.000.000',
#   'judul': 'velg mobil terbaru tipe TOKYO L351 HSR R15X7 H8X100-114,3 ET35 SMB',
#   'kota': 'Tangerang Selatan Kota',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 5.300.000',
#   'judul': 'Harga velg mobil Hsr type Yuzawa-JD6030-HSR-Ring-17',
#   'kota': 'Karawang Kab.',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 400.000',
#   'judul': 'KACA film mobil pas bulan ini coi',
#   'kota': 'Bekasi Kota',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 4.200.000',
#   'judul': 'Velg Mobil HSR Ring 15 TYPE DEUS JD6058 HSR R15X7 H5X139,7 ET-10 '
#            'BMF',
#   'kota': 'Bekasi Kota',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 4.800.000',
#   'judul': 'Velg Mobil Murah TOKYO 657 HSR Ring 16',
#   'kota': 'Padang Kota',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 195.000',
#   'judul': 'body cover selimut pelindung body mobil suzuki ertiga',
#   'kota': 'Gresik Kab.',
#   'tanggal': '11:18'},
#  {'harga': 'Rp 4.300.000',
#   'judul': 'velg mobil racing dockland 771 hsr ring 15 buat baleno swift '
#            'avanza',
#   'kota': 'Gunung Sitoli Kota',
#   'tanggal': '11:18'},
#  {'harga': 'Rp 1.150.000',
#   'judul': 'kaca film mobil INDONESIA hitam pekat dan cermin silver',
#   'kota': 'Bekasi Kota',
#   'tanggal': '11:18'},
#  {'harga': 'Rp 5.600.000',
#   'judul': 'Velg Mobil HSR Wheel - NARA LG37 R17',
#   'kota': 'Jakarta Pusat',
#   'tanggal': '11:18'},
#  {'harga': 'Rp 4.200.000',
#   'judul': 'velg mobil hsr tipe diehard ring 15 hole 6 cocok fortuner strada '
#            'dll',
#   'kota': 'Gunung Sitoli Kota',
#   'tanggal': '11:18'},
#  {'harga': 'Rp 210.000.000',
#   'judul': '[Mobil Baru] Xpander 2019 program mudik asik dp 30 jt an* proses '
#            'kilat',
#   'kota': 'Yogyakarta Kota',
#   'tanggal': '07:23'},
#  {'harga': 'Rp 136.000.000',
#   'judul': '[Mobil Baru] Honda Brio DP 10jtn atau angsuran 2 Jtn',
#   'kota': 'Bekasi Kota',
#   'tanggal': 'kemarin'},
#  {'harga': 'Rp 4.250.000',
#   'judul': 'mobil aki rubicon lisensi',
#   'kota': 'Denpasar Kota',
#   'tanggal': '25  Mar'},
#  {'harga': 'Rp 4.000.000',
#   'judul': 'velg mobil Suzuki tipe TOKYO L351 HSR R15X7 H8X100-114,3 ET35 SMG',
#   'kota': 'Tangerang Selatan Kota',
#   'tanggal': '11:20'},
#  {'harga': 'Rp 575.000',
#   'judul': 'CARA mengatasi limbung pd mobil?Gampang lngsng psang Damper '
#            'BALANCE aj',
#   'kota': 'Kotawaringin Barat Kab.',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 4.200.000',
#   'judul': 'velg mobil directional hsr ring 15 hole 5x139,7 cocok feroza taft',
#   'kota': 'Gunung Sitoli Kota',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 300.000',
#   'judul': 'kikim vrsi jawon | Garnish Lampu Depan Mobil : GRAND ALL NEW CR-V',
#   'kota': 'Yogyakarta Kota',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 280.000',
#   'judul': 'Selimut mobil h2r bandung bahan kualitas halus46',
#   'kota': 'Serang Kab.',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 175.000',
#   'judul': 'Coper body selimut mobil door mirror m1 suzuki karimun estilo',
#   'kota': 'Gresik Kab.',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 4.000.000',
#   'judul': 'velg mobil terbaru tipe TOKYO L351 HSR R15X7 H8X100-114,3 ET35 SMB',
#   'kota': 'Tangerang Selatan Kota',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 5.300.000',
#   'judul': 'Harga velg mobil Hsr type Yuzawa-JD6030-HSR-Ring-17',
#   'kota': 'Karawang Kab.',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 400.000',
#   'judul': 'KACA film mobil pas bulan ini coi',
#   'kota': 'Bekasi Kota',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 4.200.000',
#   'judul': 'Velg Mobil HSR Ring 15 TYPE DEUS JD6058 HSR R15X7 H5X139,7 ET-10 '
#            'BMF',
#   'kota': 'Bekasi Kota',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 4.800.000',
#   'judul': 'Velg Mobil Murah TOKYO 657 HSR Ring 16',
#   'kota': 'Padang Kota',
#   'tanggal': '11:19'},
#  {'harga': 'Rp 195.000',
#   'judul': 'body cover selimut pelindung body mobil suzuki ertiga',
#   'kota': 'Gresik Kab.',
#   'tanggal': '11:18'},
#  {'harga': 'Rp 4.300.000',
#   'judul': 'velg mobil racing dockland 771 hsr ring 15 buat baleno swift '
#            'avanza',
#   'kota': 'Gunung Sitoli Kota',
#   'tanggal': '11:18'},
#  {'harga': 'Rp 1.150.000',
#   'judul': 'kaca film mobil INDONESIA hitam pekat dan cermin silver',
#   'kota': 'Bekasi Kota',
#   'tanggal': '11:18'},
#  {'harga': 'Rp 5.600.000',
#   'judul': 'Velg Mobil HSR Wheel - NARA LG37 R17',
#   'kota': 'Jakarta Pusat',
#   'tanggal': '11:18'},
#  {'harga': 'Rp 4.200.000',
#   'judul': 'velg mobil hsr tipe diehard ring 15 hole 6 cocok fortuner strada '
#            'dll',
#   'kota': 'Gunung Sitoli Kota',
#   'tanggal': '11:18'}]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5f4648e1a67e> in <module>
#      24 from pprint import pprint
#      25 pprint(hasil)
# ---> 26 df = pd.DataFrame(hasil)
#      27 df.to_csv('olx-hal12.csv')
#
# NameError: name 'pd' is not defined
