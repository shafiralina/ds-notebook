# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
link='https://www.olx.co.id/all-results/q-mobil/?page={}'

# %%
req = requests.get(link.format(1))
soup = BeautifulSoup(req.text, 'lxml')
kumpulan_page = soup.find_all('span',class_='item inline-block')
page_terakhir = kumpulan_page[-1].a['href'].split('=')
page_terakhir = page_terakhir[-1]

# %%
kumpulan_link=[]
hasil=[]
for i in range(1, int(page_terakhir)+1):
    kumpulan_link.append(link.format(i))
    
for link in kumpulan_link[:2]:
    req_mobil = requests.get(link)
    soup_mobil = BeautifulSoup(req_mobil.text, 'lxml')
    seluruh_judul_page = soup_mobil.find_all('a', {'class':'marginright5 link linkWithHash detailsLink'})
    seluruh_harga_page = soup_mobil.find_all('p', {'class':'price large margintop10'})
    seluruh_kota_page = soup_mobil.find_all('p', {'class':'color-9 lheight14 margintop3'})
    seluruh_tanggal_page = soup_mobil.find_all('td', {'class':'rel tcenter'})
    
    
    for judul, harga, kota, tanggal in zip(seluruh_judul_page, seluruh_harga_page, seluruh_kota_page, seluruh_tanggal_page):
        item = {}
        item['judul'] = judul.text.strip()
        item['harga'] = harga.text.strip()
        item['tanggal'] = tanggal.text.strip()
        item['kota'] = kota.find('span').text.strip()
        item['link']=judul['href']
        hasil.append(item)
    
    
from pprint import pprint
pprint(hasil)
df = pd.DataFrame(hasil)
df.to_csv('olx-hal12.csv')
# Out:
# [{'harga': 'Rp 2.200.000',
#   'judul': 'Jasa Poles dan Coating Mobil/Motor Panggilan HARGA PROMO RAMADHAN!',
#   'kota': 'Banda Aceh Kota',
#   'link': 'https://www.olx.co.id/iklan/jasa-poles-dan-coating-mobil-motor-panggilan-harga-promo-ramadhan-IDzvzDk.html?ad_type=HL#773885e671;promoted',
#   'tanggal': '7  Mei'},
#  {'harga': 'Rp 261.000.000',
#   'judul': '[Mobil Baru] Honda Jazz Promo Honda Spesial Bulan Ini',
#   'kota': 'Bekasi Kota',
#   'link': 'https://www.olx.co.id/iklan/mobil-baru-honda-jazz-promo-honda-spesial-bulan-ini-IDzwNVc.html?ad_type=HL#773885e671;promoted',
#   'tanggal': '6  Mei'},
#  {'harga': 'Rp 200.000',
#   'judul': 'Salon Mobil ,Paint Protection ,Nano Coating dan Poles Body '
#            'Panggilan',
#   'kota': 'Surabaya Kota',
#   'link': 'https://www.olx.co.id/iklan/salon-mobil-paint-protection-nano-coating-dan-poles-body-panggilan-IDzwnAw.html?ad_type=HL#773885e671;promoted',
#   'tanggal': '5  Mei'},
#  {'harga': 'Rp 500.000',
#   'judul': 'header ya bos buat mobil agan barang d sesuaikan jenis tipe mobil '
#            'ya',
#   'kota': 'Purbalingga Kab.',
#   'link': 'https://www.olx.co.id/iklan/header-ya-bos-buat-mobil-agan-barang-d-sesuaikan-jenis-tipe-mobil-ya-IDzyYBU.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 5.600.000',
#   'judul': 'velg mobil hiroshima ring 17 lobang 10 bisa cash/credit',
#   'kota': 'Pekanbaru Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-hiroshima-ring-17-lobang-10-bisa-cash-credit-IDzyYFR.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 4.200.000',
#   'judul': 'velg mobil fortuner tipe keeler hsr r15 hole 6 import',
#   'kota': 'Gunung Sitoli Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-fortuner-tipe-keeler-hsr-r15-hole-6-import-IDzyYFZ.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 5.300.000',
#   'judul': 'velg mobil murah dikota bogor-ARROW JD803 HSR R17X7 H8X100-114,3 '
#            'ET45',
#   'kota': 'Bogor Kab.',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-murah-dikota-bogor-arrow-jd803-hsr-r17x7-h8x100-114-3-et45-IDzyYFe.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 6.000.000',
#   'judul': 'Cash atau kredit velg Ring 17 bisa untuk mobil livina xenia jazz '
#            'Yaris',
#   'kota': 'Bandung Kota',
#   'link': 'https://www.olx.co.id/iklan/cash-atau-kredit-velg-ring-17-bisa-untuk-mobil-livina-xenia-jazz-yaris-IDzyYEg.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 15.900.000',
#   'judul': '#Android Mobile Gan ,, IPhone Xs Max 64gb Asli apple 100% Inter',
#   'kota': 'Jakarta Selatan',
#   'link': 'https://www.olx.co.id/iklan/android-mobile-gan-iphone-xs-max-64gb-asli-apple-100-inter-IDzyYEI.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 4.000.000',
#   'judul': 'velek mobil ne7 R15 rata 65 jakarta selatan',
#   'kota': 'Jakarta Selatan',
#   'link': 'https://www.olx.co.id/iklan/velek-mobil-ne7-r15-rata-65-jakarta-selatan-IDzyYF4.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 325.000',
#   'judul': 'kikim vrsi jawon | Sillplate Belakang Activo Mobil : X-PANDER',
#   'kota': 'Yogyakarta Kota',
#   'link': 'https://www.olx.co.id/iklan/kikim-vrsi-jawon-sillplate-belakang-activo-mobil-x-pander-IDzyVS7.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 12.000',
#   'judul': 'jasa sewa mobil L300 di bali',
#   'kota': 'Denpasar Kota',
#   'link': 'https://www.olx.co.id/iklan/jasa-sewa-mobil-l300-di-bali-IDzyYE3.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 275.000',
#   'judul': 'kikim vrsi jawon | Talang Air Slim Mobil : X-PANDER',
#   'kota': 'Yogyakarta Kota',
#   'link': 'https://www.olx.co.id/iklan/kikim-vrsi-jawon-talang-air-slim-mobil-x-pander-IDzyXSo.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 4.300.000',
#   'judul': 'velg mobil hsr tipe kawai01 ring 15 pcd 4x100 racing altis corolla',
#   'kota': 'Gunung Sitoli Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-hsr-tipe-kawai01-ring-15-pcd-4x100-racing-altis-corolla-IDzyYCn.html?ad_type=OR#773885e671',
#   'tanggal': '11:21'},
#  {'harga': 'Rp 400.000',
#   'judul': 'kaca film mobil barang original',
#   'kota': 'Jakarta Selatan',
#   'link': 'https://www.olx.co.id/iklan/kaca-film-mobil-barang-original-IDzyYCB.html?ad_type=OR#773885e671',
#   'tanggal': '11:21'},
#  {'harga': 'Rp 4.200.000',
#   'judul': 'velg mobil racing Jungle HSR ring 15 hole 6 import triton everest '
#            'dll',
#   'kota': 'Gunung Sitoli Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-racing-jungle-hsr-ring-15-hole-6-import-triton-everest-dll-IDzyYBx.html?ad_type=OR#773885e671',
#   'tanggal': '11:21'},
#  {'harga': 'Rp 5.600.000',
#   'judul': 'Velg Mobil Murah OSTER JD106 HSR Ring 17',
#   'kota': 'Padang Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-murah-oster-jd106-hsr-ring-17-IDzyYAP.html?ad_type=OR#773885e671',
#   'tanggal': '11:21'},
#  {'harga': 'Rp 4.000.000',
#   'judul': 'velg mobil yaris tipe emission jd5178 hsr ring 15 hole 4x100 '
#            'Venice',
#   'kota': 'Gunung Sitoli Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-yaris-tipe-emission-jd5178-hsr-ring-15-hole-4x100-venice-IDzyYAL.html?ad_type=OR#773885e671',
#   'tanggal': '11:20'},
#  {'harga': 'Rp 4.500.000',
#   'judul': 'velg mobil 142 HSR R16X7 H4X100 ET42 SATIN BLACK',
#   'kota': 'Cirebon Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-142-hsr-r16x7-h4x100-et42-satin-black-IDzyYAl.html?ad_type=OR#773885e671',
#   'tanggal': '11:20'},
#  {'harga': 'Rp 239.500.000',
#   'judul': '[Mobil Baru] HONDA JAZZ 2019 DAPAT THR MELIMPAH',
#   'kota': 'Bandung Kota',
#   'link': 'https://www.olx.co.id/iklan/mobil-baru-honda-jazz-2019-dapat-thr-melimpah-IDzu4T9.html?ad_type=HL#773885e671;promoted',
#   'tanggal': '3  Mei'},
#  {'harga': 'Rp 550.000',
#   'judul': 'credit audio mobil lian mandiri',
#   'kota': 'Depok Kota',
#   'link': 'https://www.olx.co.id/iklan/credit-audio-mobil-lian-mandiri-IDzpQ4P.html?ad_type=HL#773885e671;promoted',
#   'tanggal': '26  Apr'},
#  {'harga': 'Rp 200.000',
#   'judul': 'poles salon mobil panggilan',
#   'kota': 'Surabaya Kota',
#   'link': 'https://www.olx.co.id/iklan/poles-salon-mobil-panggilan-IDz0Dfw.html?ad_type=HL#773885e671;promoted',
#   'tanggal': '15  Mar'},
#  {'harga': 'Rp 500.000',
#   'judul': 'header ya bos buat mobil agan barang d sesuaikan jenis tipe mobil '
#            'ya',
#   'kota': 'Purbalingga Kab.',
#   'link': 'https://www.olx.co.id/iklan/header-ya-bos-buat-mobil-agan-barang-d-sesuaikan-jenis-tipe-mobil-ya-IDzyYBU.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 5.600.000',
#   'judul': 'velg mobil hiroshima ring 17 lobang 10 bisa cash/credit',
#   'kota': 'Pekanbaru Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-hiroshima-ring-17-lobang-10-bisa-cash-credit-IDzyYFR.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 4.200.000',
#   'judul': 'velg mobil fortuner tipe keeler hsr r15 hole 6 import',
#   'kota': 'Gunung Sitoli Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-fortuner-tipe-keeler-hsr-r15-hole-6-import-IDzyYFZ.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 5.300.000',
#   'judul': 'velg mobil murah dikota bogor-ARROW JD803 HSR R17X7 H8X100-114,3 '
#            'ET45',
#   'kota': 'Bogor Kab.',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-murah-dikota-bogor-arrow-jd803-hsr-r17x7-h8x100-114-3-et45-IDzyYFe.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 6.000.000',
#   'judul': 'Cash atau kredit velg Ring 17 bisa untuk mobil livina xenia jazz '
#            'Yaris',
#   'kota': 'Bandung Kota',
#   'link': 'https://www.olx.co.id/iklan/cash-atau-kredit-velg-ring-17-bisa-untuk-mobil-livina-xenia-jazz-yaris-IDzyYEg.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 15.900.000',
#   'judul': '#Android Mobile Gan ,, IPhone Xs Max 64gb Asli apple 100% Inter',
#   'kota': 'Jakarta Selatan',
#   'link': 'https://www.olx.co.id/iklan/android-mobile-gan-iphone-xs-max-64gb-asli-apple-100-inter-IDzyYEI.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 4.000.000',
#   'judul': 'velek mobil ne7 R15 rata 65 jakarta selatan',
#   'kota': 'Jakarta Selatan',
#   'link': 'https://www.olx.co.id/iklan/velek-mobil-ne7-r15-rata-65-jakarta-selatan-IDzyYF4.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 325.000',
#   'judul': 'kikim vrsi jawon | Sillplate Belakang Activo Mobil : X-PANDER',
#   'kota': 'Yogyakarta Kota',
#   'link': 'https://www.olx.co.id/iklan/kikim-vrsi-jawon-sillplate-belakang-activo-mobil-x-pander-IDzyVS7.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 12.000',
#   'judul': 'jasa sewa mobil L300 di bali',
#   'kota': 'Denpasar Kota',
#   'link': 'https://www.olx.co.id/iklan/jasa-sewa-mobil-l300-di-bali-IDzyYE3.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 275.000',
#   'judul': 'kikim vrsi jawon | Talang Air Slim Mobil : X-PANDER',
#   'kota': 'Yogyakarta Kota',
#   'link': 'https://www.olx.co.id/iklan/kikim-vrsi-jawon-talang-air-slim-mobil-x-pander-IDzyXSo.html?ad_type=OR#773885e671',
#   'tanggal': '11:22'},
#  {'harga': 'Rp 4.300.000',
#   'judul': 'velg mobil hsr tipe kawai01 ring 15 pcd 4x100 racing altis corolla',
#   'kota': 'Gunung Sitoli Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-hsr-tipe-kawai01-ring-15-pcd-4x100-racing-altis-corolla-IDzyYCn.html?ad_type=OR#773885e671',
#   'tanggal': '11:21'},
#  {'harga': 'Rp 400.000',
#   'judul': 'kaca film mobil barang original',
#   'kota': 'Jakarta Selatan',
#   'link': 'https://www.olx.co.id/iklan/kaca-film-mobil-barang-original-IDzyYCB.html?ad_type=OR#773885e671',
#   'tanggal': '11:21'},
#  {'harga': 'Rp 4.200.000',
#   'judul': 'velg mobil racing Jungle HSR ring 15 hole 6 import triton everest '
#            'dll',
#   'kota': 'Gunung Sitoli Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-racing-jungle-hsr-ring-15-hole-6-import-triton-everest-dll-IDzyYBx.html?ad_type=OR#773885e671',
#   'tanggal': '11:21'},
#  {'harga': 'Rp 5.600.000',
#   'judul': 'Velg Mobil Murah OSTER JD106 HSR Ring 17',
#   'kota': 'Padang Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-murah-oster-jd106-hsr-ring-17-IDzyYAP.html?ad_type=OR#773885e671',
#   'tanggal': '11:21'},
#  {'harga': 'Rp 4.000.000',
#   'judul': 'velg mobil yaris tipe emission jd5178 hsr ring 15 hole 4x100 '
#            'Venice',
#   'kota': 'Gunung Sitoli Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-yaris-tipe-emission-jd5178-hsr-ring-15-hole-4x100-venice-IDzyYAL.html?ad_type=OR#773885e671',
#   'tanggal': '11:20'},
#  {'harga': 'Rp 4.500.000',
#   'judul': 'velg mobil 142 HSR R16X7 H4X100 ET42 SATIN BLACK',
#   'kota': 'Cirebon Kota',
#   'link': 'https://www.olx.co.id/iklan/velg-mobil-142-hsr-r16x7-h4x100-et42-satin-black-IDzyYAl.html?ad_type=OR#773885e671',
#   'tanggal': '11:20'}]
